# %%
import cv2
import mediapipe as mp
import time

# %%
cap = cv2.VideoCapture(0)
mpHands = mp.solutions.hands
hands = mpHands.Hands()
mpDraw = mp.solutions.drawing_utils

pTime = 0
cTime = 0

while True:
    success , img = cap.read()
    imgRGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:

            #landmarks location print
            for id , lm in enumerate(handLms.landmark):
                #print(id,lm)
                h,w,c = img.shape
                cx,cy = int(lm.x*w),(lm.y*h)
                print(id,cx,cy)

                #make a circle at specific point
                # if id==4:
                #     cv2.circle(img,(cx,cy),15,(255,0,0),cv2.FILLED)
                    
            #mpDraw.draw_landmarks(img,handLms) #draws landmarks only
            mpDraw.draw_landmarks(img,handLms, mpHands.HAND_CONNECTIONS) #lines with points


    #frame rate
    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime

    #frame rate text
    cv2.putText(img,str(int(fps)),(10,70),cv2.FONT_HERSHEY_PLAIN,3,(255,0,255),3)

    cv2.imshow("Image",img)
    cv2.waitKey(1)
# Out:
# 0 296 410.25672912597656
# 1 324 399.5847702026367
# 2 349 375.5646514892578
# 3 365 351.8100070953369
# 4 379 331.65355682373047
# 5 326 336.9533157348633
# 6 337 309.281644821167
# 7 344 291.5913391113281
# 8 350 276.1951732635498
# 9 305 331.3095188140869
# 10 310 297.7379608154297
# 11 314 277.1073818206787
# 12 319 259.702091217041
# 13 285 334.85581398010254
# 14 284 302.04036712646484
# 15 285 280.8530616760254
# 16 288 262.96093940734863
# 17 265 346.77083015441895
# 18 253 323.3821105957031
# 19 244 307.58520126342773
# 20 239 292.3744869232178
# 0 296 388.302526473999
# 1 326 368.8029098510742
# 2 350 344.2708396911621
# 3 369 323.1240463256836
# 4 383 303.68176460266113
# 5 329 305.1932144165039
# 6 339 277.64513969421387
# 7 346 259.28486824035645
# 8 353 243.39609146118164
# 9 309 301.1722183227539
# 10 312 270.521879196167
# 11 317 250.3824234008789
# 12 322 232.95899391174316
# 13 288 305.28531074523926
# 14 288 275.92626571655273
# 15 288 254.5414638519287
# ...
